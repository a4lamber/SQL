# %%
'''
 # @ Author: Yixiang Zhang
 # @ Create Time: 2022-08-13 15:09:45
 # @ Modified by: Yixiang Zhang
 # @ Modified time: 2022-08-13 15:10:04
 # @ Description:
    goof around with the yfinance module for stock price.
    https://pypi.org/project/yfinance/
 '''


import pandas as pd
import yfinance as yf



# choose the symbol for the stock
tickerSymbol = "BILI"
# tickerSymbol = "AMZN"


# using the Ticker module to access ticker data
tickerData = yf.Ticker(tickerSymbol)

# %%
# look at company info
tickerData.info
# Out:
# {'zip': '200433',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 12281,
#  'longBusinessSummary': "Bilibili Inc. provides online entertainment services for the young generations in the People's Republic of China. Its platform offers a range of content, including video services, mobile games, and value-added service, as well as ACG-related comic and audio content. The company's video services include professional user generated videos, occupationally generated videos, and live broadcasting. Bilibili Inc. was founded in 2009 and is headquartered in Shanghai, the People's Republic of China.",
#  'city': 'Shanghai',
#  'phone': '86 21 2509 9255',
#  'country': 'China',
#  'companyOfficers': [],
#  'website': 'https://www.bilibili.com',
#  'maxAge': 1,
#  'address1': 'Building 3',
#  'industry': 'Electronic Gaming & Multimedia',
#  'address2': 'Guozheng Center No. 485 Zhengli Road Yangpu District',
#  'ebitdaMargins': -0.23211999,
#  'profitMargins': -0.39771,
# ...

# %%
tickerData.major_holders
# Out:
#         0                                      1
# 0   3.27%        % of Shares Held by All Insider
# 1  37.97%       % of Shares Held by Institutions
# 2  39.26%        % of Float Held by Institutions
# 3     378  Number of Institutions Holding Shares

# %%
tickerData.institutional_holders
# Out:
#                                        Holder    Shares Date Reported   % Out  \
# 0                                    FMR, LLC  19482423    2022-03-30  0.0635
# 1                   Alibaba Group Holding Ltd  10000000    2022-03-30  0.0326
# 2             Yiheng Capital Management, L.P.   9356881    2022-03-30  0.0305
# 3                              Blackrock Inc.   7773101    2022-03-30  0.0253
# 4                              Morgan Stanley   6798188    2022-03-30  0.0222
# 5  Allspring Global Investments Holdings, LLC   6338703    2022-06-29  0.0207
# 6        Artisan Partners Limited Partnership   5346724    2022-03-30  0.0174
# 7                    State Street Corporation   5094637    2022-03-30  0.0166
# 8           Norges Bank Investment Management   2702688    2021-12-30  0.0088
# 9                           Marshall Wace LLP   2066332    2022-03-30  0.0067
#
#        Value
# 0  494853536
# 1  253999996
# 2  237664773
# 3  197436762
# 4  172673972
# 5  161003053
# ...

# %%
tickerData.cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                               -2.090814e+10 -6.172468e+09
# Change To Liabilities                      1.551398e+09  1.550889e+09
# Total Cashflows From Investing Activities -2.457811e+10 -8.906821e+09
# Net Borrowings                             1.122664e+10  5.708636e+09
# Total Cash From Financing Activities       3.038915e+10  8.335419e+09
# Change To Operating Activities            -1.208464e+09  2.992330e+08
# Issuance Of Stock                          1.928857e+10  2.818024e+09
# Net Income                                -6.789228e+09 -3.011704e+09
# Change In Cash                             2.844999e+09 -2.845510e+08
# Effect Of Exchange Rate                   -3.190340e+08 -4.662520e+08
# Total Cash From Operating Activities      -2.647008e+09  7.531030e+08
# Depreciation                               2.603700e+09  1.817876e+09
# ...
